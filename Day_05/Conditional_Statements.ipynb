# %% [markdown]
# #Conditional Statements
#  *Conditional statement is used to make decisions based on conditions.
#   They are of three types:
#   1. If statement
#   2. Elif statement
#   3. Else statement

# %% [markdown]
# Example 1 : Check voting eligibilty

# %%
age = int(input("Enter your age: "))

if age >= 18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# Enter your age: 28
# You are eligible to vote

# %% [markdown]
# Example 2 : Grade calculator

# %%
marks = int(input("Enter your marks : "))

if (marks >= 90):
  print("Grade A")
elif (marks >= 80):
  print("Grade B")
elif (marks >= 70):
  print("Grade C")
else:
  print("Grade D")
# Out:
# Enter your marks : 82
# Grade B

# %% [markdown]
# Example 3 : Check whether a number is positive, negative, or zero.

# %%
num = float(input("Enter a number : "))

if ( num > 0):
  print("Number is positive")
elif (num < 0):
  print("Number is negative")
else:
  print("Number is zero")
# Out:
# Enter a number : 5
# Number is positive

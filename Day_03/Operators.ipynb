# %%
a = 10
b = 6

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)
# Out:
# 16
# 4
# 60
# 1.6666666666666667
# 1
# 4
# 1000000

# %% [markdown]
# Learn various airthmetic operators.

# %%
print(10 > 6)
print(10 < 6)
print(10 != 6)
print(10 == 6)
# Out:
# True
# False
# True
# False

# %% [markdown]
# Learn various comparison operators.

# %%
length = 12
breadth = 5

area = length*breadth

print(area)
# Out:
# 60

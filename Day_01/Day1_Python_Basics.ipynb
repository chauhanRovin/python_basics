# %%
print("HELLO, Data Analytics!")
print("My Name is Rovin Chauhan")
print("My journey to  become a Data Analyst")
# Out:
# HELLO, Data Analytics!
# My Name is Rovin Chauhan
# My journey to  become a Data Analyst
